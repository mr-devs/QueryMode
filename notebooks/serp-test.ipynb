# %%
import os

from helpers.serp import get_search_results

from serpapi import GoogleSearch

# %%
api_key = os.environ.get("SERP_API_KEY")
api_key
# Out:
# '5b378359ac84e0eee3075a14f63c46565824323619125d7e15482d74ee2821c2'

# %%
results = get_search_results(
    query="What is the best way to clean a wound?",
    location="Austin, Texas, United States",
    api_key=api_key,
)

# %%
results.keys()
# Out:
# dict_keys(['search_metadata', 'search_parameters', 'search_information', 'related_questions', 'ai_overview', 'organic_results', 'top_stories_link', 'top_stories_serpapi_link', 'related_searches', 'discussions_and_forums', 'pagination', 'serpapi_pagination'])

# %%
results["organic_results"]
# Out:
# [{'position': 1,
#   'title': 'How Should I Clean a Wound?',
#   'link': 'https://www.webmd.com/first-aid/relieving-wound-pain',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.webmd.com/first-aid/relieving-wound-pain&ved=2ahUKEwj-jIXw7dWLAxWC78kDHaE7GTsQFnoECBQQAQ',
#   'displayed_link': 'https://www.webmd.com › relieving-wound-pain',
#   'favicon': 'https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b0387e61ff9ee657fd5aae16c74eac1effa.png',
#   'date': 'May 1, 2023',
#   'snippet': "Rinse the wound in clear water to loosen and remove dirt and debris. · Use a soft washcloth and mild soap to clean around the wound. Don't place ...",
#   'snippet_highlighted_words': ['Rinse the wound in clear water'],
#   'source': 'WebMD'},
#  {'position': 2,
#   'title': 'Wound Care at Home: How to Clean a Wound',
#   'link': 'https://www.baystatehealth.org/articles/wound-care',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.baystatehealth.org/articles/wound-care&ved=2ahUKEwj-jIXw7dWLAxWC78kDHaE7GTsQFnoECBMQAQ',
#   'displayed_link': 'https://www.baystatehealth.org › articles › wound-care',
#   'favicon': 'https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b035fd3a2129fe95fee200a6d96277f95fc.png',
#   'date': 'Jun 13, 2023',
#   'snippet': 'Clean the wound: Gently wash the area with water and try to remove any debris that may be lodged in the wound. Canto advises not using alcohol ...',
#   'snippet_highlighted_words': ['Gently wash the area with water'],
#   'source': 'Baystate Health'},
#  {'position': 3,
#   'title': 'Cuts and scrapes: First aid',
#   'link': 'https://www.mayoclinic.org/first-aid/first-aid-cuts/basics/art-20056711',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.mayoclinic.org/first-aid/first-aid-cuts/basics/art-20056711&ved=2ahUKEwj-jIXw7dWLAxWC78kDHaE7GTsQFnoECCkQAQ',
#   'displayed_link': 'https://www.mayoclinic.org › basics › art-20056711',
#   'favicon': 'https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b03ce779a026aea39ce86e4ba6b9da4dad1.png',
#   'snippet': "Rinse the wound with water. Keeping the wound under running water will lower the risk of infection. Wash around the wound with soap. But don't get soap in the ...",
#   'snippet_highlighted_words': ['Rinse the wound with water'],
#   'source': 'Mayo Clinic'},
#  {'position': 4,
#   'title': 'Surgical wound care - open Information',
#   'link': 'https://www.mountsinai.org/health-library/selfcare-instructions/surgical-wound-care-open',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.mountsinai.org/health-library/selfcare-instructions/surgical-wound-care-open&ved=2ahUKEwj-jIXw7dWLAxWC78kDHaE7GTsQFnoECCoQAQ',
#   'displayed_link': 'https://www.mountsinai.org › selfcare-instructions › sur...',
#   'favicon': 'https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b030210099a99d952c42912d9306c15638b.png',
#   'snippet': 'Use a normal saline solution (salt water) or mild soapy water. Soak the gauze or cloth in the saline solution or soapy water, and gently dab or wipe the skin ...',
#   'snippet_highlighted_words': ['Use a normal saline solution (salt water) or mild soapy water'],
#   'source': 'Mount Sinai'},
#  {'position': 5,
#   'title': 'Wound Care: How to Care for an Open Wound or Cut',
#   'link': 'https://health.clevelandclinic.org/handling-injuries-from-small-cuts-to-serious-wounds',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://health.clevelandclinic.org/handling-injuries-from-small-cuts-to-serious-wounds&ved=2ahUKEwj-jIXw7dWLAxWC78kDHaE7GTsQFnoECCsQAQ',
#   'displayed_link': 'https://health.clevelandclinic.org › handling-injuries-fro...',
#   'favicon': 'https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b03b508cb38d6c914a8e84e691ce85228aa.png',
#   'date': 'Jun 2, 2022',
#   'snippet': "Wash out the wound with a large quantity of warm, soapy water as soon as possible. It's also OK to get in the shower and let copious amounts of warm, soapy ...",
#   'snippet_highlighted_words': ['Wash out the wound with a large quantity of warm, soapy water'],
#   'source': 'Cleveland Clinic Health Essentials'},
#  {'position': 6,
#   'title': 'Basic Wound Care',
#   'link': 'https://www.uhs.wisc.edu/medical/wound-care/',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.uhs.wisc.edu/medical/wound-care/&ved=2ahUKEwj-jIXw7dWLAxWC78kDHaE7GTsQFnoECC0QAQ',
#   'displayed_link': 'https://www.uhs.wisc.edu › Medical Services',
#   'favicon': 'https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b03dc9c025e54edd2888ca016dac79498f7.png',
#   'snippet': 'Immediately after the injury, wash thoroughly with clean water and mild soap. · For burn wounds, run cool water over the area or apply a cool, wet cloth. · Apply ...',
#   'snippet_highlighted_words': ['wash thoroughly with clean water and mild soap'],
#   'source': 'University of Wisconsin–Madison'},
#  {'position': 7,
#   'title': 'Care for a Skin Wound - MyHealth Alberta',
#   'link': 'https://myhealth.alberta.ca/Health/pages/conditions.aspx?hwid=tp22233spec',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://myhealth.alberta.ca/Health/pages/conditions.aspx%3Fhwid%3Dtp22233spec&ved=2ahUKEwj-jIXw7dWLAxWC78kDHaE7GTsQFnoECCgQAQ',
#   'displayed_link': 'https://myhealth.alberta.ca › Health › pages › conditions',
#   'favicon': 'https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b03ccabb2956924b4ed5a8e9fb7cc0fb65b.png',
#   'snippet': 'Wash the wound under running tap water (the more the better) to remove all the dirt, debris, and bacteria from the wound. Scrub gently with a face cloth ...',
#   'snippet_highlighted_words': ['Wash the wound under running tap water'],
#   'source': 'MyHealth Alberta'},
#  {'position': 8,
#   'title': 'Slideshow: Wound Care True or False',
#   'link': 'https://www.webmd.com/first-aid/ss/slideshow-wound-care-dos-and-donts',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.webmd.com/first-aid/ss/slideshow-wound-care-dos-and-donts&ved=2ahUKEwj-jIXw7dWLAxWC78kDHaE7GTsQFnoECDAQAQ',
#   'displayed_link': 'https://www.webmd.com › first-aid › slideshow-wound-c...',
#   'favicon': 'https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b03b3777fb20dfff1339bdcde248677496b.png',
#   'date': 'Aug 29, 2024',
#   'snippet': 'The best way to clean a minor wound is with cool running water and mild soap. Rinse the wound for at least five minutes to remove dirt, debris, and bacteria.',
#   'snippet_highlighted_words': ['cool running water and mild soap'],
#   'sitelinks': {'inline': [{'title': 'Clean With Hydrogen Peroxide...',
#      'link': 'https://www.webmd.com/first-aid/ss/slideshow-wound-care-dos-and-donts#:~:text=Clean%20With%20Hydrogen%20Peroxide%20or%20Alcohol%3F%20FALSE,-Using%20hydrogen%20peroxide%20or%20rubbing'},
#     {'title': 'Keep Injuries Moist? True',
#      'link': 'https://www.webmd.com/first-aid/ss/slideshow-wound-care-dos-and-donts#:~:text=Keep%20Injuries%20Moist%3F%20TRUE,-Keeping%20wounds%20moist%20helps%20wounds'},
#     {'title': 'Leave Scrapes Uncovered?...',
#      'link': 'https://www.webmd.com/first-aid/ss/slideshow-wound-care-dos-and-donts#:~:text=Leave%20Scrapes%20Uncovered%3F%20FALSE,-A%20bandage%20can%20protect%20the'}]},
#   'source': 'WebMD'},
#  {'position': 9,
#   'title': 'Caring for Cuts, Scrapes, and Wounds',
#   'link': 'https://www.aafp.org/pubs/afp/issues/2002/0715/p315.html',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.aafp.org/pubs/afp/issues/2002/0715/p315.html&ved=2ahUKEwj-jIXw7dWLAxWC78kDHaE7GTsQFnoECC4QAQ',
#   'displayed_link': 'https://www.aafp.org › pubs › afp › issues',
#   'favicon': 'https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b03bd489c2e7264995e8bac48cda899e2d6.png',
#   'date': 'Jul 15, 2002',
#   'snippet': 'The best way to clean a cut, scrape, or puncture wound (such as from a nail) is with cool water. You can hold the wound under running water or fill a tub with ...',
#   'snippet_highlighted_words': ['cool water'],
#   'source': 'American Academy of Family Physicians | AAFP'}]

# %%
def format_search_results(results):
    """
    Formats a list of search results into markdown similar to Google's search result display,
    including ancillary details (like date) only if they are present.

    Parameters:
    -----------
    results : list of dict
        A list of dictionaries, where each dictionary contains:
            - title (str): The title of the search result.
            - link (str): The actual link to the page.
            - displayed_link (str): The shortened/displayed link.
            - favicon (str): URL to the favicon image.
            - date (str, optional): The publication date of the result.
            - snippet (str): The description/snippet of the result.
            - snippet_highlighted_words (list, optional): Words to highlight in the snippet.
            - source (str): The source/website name.

    Returns:
    --------
    str
        A markdown-formatted string representing the search results.
    """
    markdown = ""
    for result in results:
        # Favicon and source
        markdown += f"![favicon]({result['favicon']}) **{result['source']}**  \n"

        # Displayed link
        markdown += f"[{result['displayed_link']}]({result['link']})  \n"

        # Title (as clickable link)
        markdown += f"### [{result['title']}]({result['link']})  \n"

        # Snippet with highlighted words
        snippet = result.get("snippet", "")
        for word in result.get("snippet_highlighted_words", []):
            snippet = snippet.replace(word, f"**{word}**")

        # Include date if present
        if "date" in result and result["date"]:
            markdown += f"*{result['date']}* — {snippet}  \n\n"
        else:
            markdown += f"{snippet}  \n\n"

    return markdown

# %%
print(format_search_results(results["organic_results"]))
# Out:
# ![favicon](https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b0387e61ff9ee657fd5aae16c74eac1effa.png) **WebMD**
# [https://www.webmd.com › relieving-wound-pain](https://www.webmd.com/first-aid/relieving-wound-pain)
# ### [How Should I Clean a Wound?](https://www.webmd.com/first-aid/relieving-wound-pain)
# *May 1, 2023* — **Rinse the wound in clear water** to loosen and remove dirt and debris. · Use a soft washcloth and mild soap to clean around the wound. Don't place ...
#
# ![favicon](https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b035fd3a2129fe95fee200a6d96277f95fc.png) **Baystate Health**
# [https://www.baystatehealth.org › articles › wound-care](https://www.baystatehealth.org/articles/wound-care)
# ### [Wound Care at Home: How to Clean a Wound](https://www.baystatehealth.org/articles/wound-care)
# *Jun 13, 2023* — Clean the wound: **Gently wash the area with water** and try to remove any debris that may be lodged in the wound. Canto advises not using alcohol ...
#
# ![favicon](https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b03ce779a026aea39ce86e4ba6b9da4dad1.png) **Mayo Clinic**
# [https://www.mayoclinic.org › basics › art-20056711](https://www.mayoclinic.org/first-aid/first-aid-cuts/basics/art-20056711)
# ### [Cuts and scrapes: First aid](https://www.mayoclinic.org/first-aid/first-aid-cuts/basics/art-20056711)
# **Rinse the wound with water**. Keeping the wound under running water will lower the risk of infection. Wash around the wound with soap. But don't get soap in the ...
#
# ![favicon](https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b030210099a99d952c42912d9306c15638b.png) **Mount Sinai**
# [https://www.mountsinai.org › selfcare-instructions › sur...](https://www.mountsinai.org/health-library/selfcare-instructions/surgical-wound-care-open)
# ### [Surgical wound care - open Information](https://www.mountsinai.org/health-library/selfcare-instructions/surgical-wound-care-open)
# **Use a normal saline solution (salt water) or mild soapy water**. Soak the gauze or cloth in the saline solution or soapy water, and gently dab or wipe the skin ...
#
# ![favicon](https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b03b508cb38d6c914a8e84e691ce85228aa.png) **Cleveland Clinic Health Essentials**
# [https://health.clevelandclinic.org › handling-injuries-fro...](https://health.clevelandclinic.org/handling-injuries-from-small-cuts-to-serious-wounds)
# ### [Wound Care: How to Care for an Open Wound or Cut](https://health.clevelandclinic.org/handling-injuries-from-small-cuts-to-serious-wounds)
# *Jun 2, 2022* — **Wash out the wound with a large quantity of warm, soapy water** as soon as possible. It's also OK to get in the shower and let copious amounts of warm, soapy ...
#
# ![favicon](https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b03dc9c025e54edd2888ca016dac79498f7.png) **University of Wisconsin–Madison**
# [https://www.uhs.wisc.edu › Medical Services](https://www.uhs.wisc.edu/medical/wound-care/)
# ### [Basic Wound Care](https://www.uhs.wisc.edu/medical/wound-care/)
# Immediately after the injury, **wash thoroughly with clean water and mild soap**. · For burn wounds, run cool water over the area or apply a cool, wet cloth. · Apply ...
#
# ![favicon](https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b03ccabb2956924b4ed5a8e9fb7cc0fb65b.png) **MyHealth Alberta**
# [https://myhealth.alberta.ca › Health › pages › conditions](https://myhealth.alberta.ca/Health/pages/conditions.aspx?hwid=tp22233spec)
# ### [Care for a Skin Wound - MyHealth Alberta](https://myhealth.alberta.ca/Health/pages/conditions.aspx?hwid=tp22233spec)
# **Wash the wound under running tap water** (the more the better) to remove all the dirt, debris, and bacteria from the wound. Scrub gently with a face cloth ...
#
# ![favicon](https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b03b3777fb20dfff1339bdcde248677496b.png) **WebMD**
# [https://www.webmd.com › first-aid › slideshow-wound-c...](https://www.webmd.com/first-aid/ss/slideshow-wound-care-dos-and-donts)
# ### [Slideshow: Wound Care True or False](https://www.webmd.com/first-aid/ss/slideshow-wound-care-dos-and-donts)
# *Aug 29, 2024* — The best way to clean a minor wound is with **cool running water and mild soap**. Rinse the wound for at least five minutes to remove dirt, debris, and bacteria.
#
# ![favicon](https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b03bd489c2e7264995e8bac48cda899e2d6.png) **American Academy of Family Physicians | AAFP**
# [https://www.aafp.org › pubs › afp › issues](https://www.aafp.org/pubs/afp/issues/2002/0715/p315.html)
# ### [Caring for Cuts, Scrapes, and Wounds](https://www.aafp.org/pubs/afp/issues/2002/0715/p315.html)
# *Jul 15, 2002* — The best way to clean a cut, scrape, or puncture wound (such as from a nail) is with **cool water**. You can hold the wound under running water or fill a tub with ...

# %%
results["organic_results"][3]
# Out:
# {'position': 4,
#  'title': 'Surgical wound care - open Information',
#  'link': 'https://www.mountsinai.org/health-library/selfcare-instructions/surgical-wound-care-open',
#  'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.mountsinai.org/health-library/selfcare-instructions/surgical-wound-care-open&ved=2ahUKEwj-jIXw7dWLAxWC78kDHaE7GTsQFnoECCoQAQ',
#  'displayed_link': 'https://www.mountsinai.org › selfcare-instructions › sur...',
#  'favicon': 'https://serpapi.com/searches/67b9040c94adcaee11472434/images/92579d67215c431a65d166c360cd7b030210099a99d952c42912d9306c15638b.png',
#  'snippet': 'Use a normal saline solution (salt water) or mild soapy water. Soak the gauze or cloth in the saline solution or soapy water, and gently dab or wipe the skin ...',
#  'snippet_highlighted_words': ['Use a normal saline solution (salt water) or mild soapy water'],
#  'source': 'Mount Sinai'}

# %%
results.keys()
# Out:
# dict_keys(['search_metadata', 'search_parameters', 'search_information', 'related_questions', 'ai_overview', 'organic_results', 'top_stories_link', 'top_stories_serpapi_link', 'related_searches', 'discussions_and_forums', 'pagination', 'serpapi_pagination'])

# %%
results["ai_overview"]
# Out:
# {'page_token': '5OWbGnicvZTbkqJIEIYv90nWG6cFbA90RxATRYE2KtLg2RsDORQIiFoo6N28y77Avs4-zRYHsbU7ZmI3NjYvioKqyvyz8iN__OG7W--v3_50omiHXykqjuMaCkPkWzUjDCgdn7cGZYc-PhjO9-PRt7i4CoGkSlDS1fn0Ynb946Cj-Va3cxl0pkd9rvlLyI_NbodezuXK-cQ9VwzM0RXL5QQwai5X7RkvDewd23gPbdurA7mSReFWax1bGyIi2WBqRZHB-_1ZIC81XLO2tefldCS_if2xBmp1mmFrCqUHZAP4NyY9ftBUAPp367ctEPDlXORVAKFDZtdvQTY6CwBU-c4lSjdBCQwE276gh3h9tZx2YjJswKkO3mER5MNYPGHur1RU2FUEguCzlQdkABF5459uK3LpJhbE-JYtVPmG8AZYyeHVyaNDUvYeEvajlQQ-XElpvCSOtWSWXgOiTERqQ1PrA3kw1AGnlYLjFzrsvribxUjpmdrw_RyojXnirGbz5C2yxuBbxoCBSwjwRwhOO4VtC4zjRJPaoMYzJQEKEQbUIiM-HaYAqJ8FFjbKcvl0T1o69UUv_-bIQJKBkif2BNReXOKh3ogQ0zcvC1kElPhiQcgcQ1KZdAEJICYxu_mxDoCSlB3hyR6ezjWRqZL5hoXAnIBeLMqxIJESYsIJyqsmFulJeb6pn36Wk8oDgUSKgQ32qucSH2G2DaJMa-kW5koRv3gk4KvSPhh8xPlm6hclF0-n_XC4Yd6idQKXtNeaajiyJdluaWpR8jBY_4Mf3_i_oNAIFP0bFLt7KLQSiru2kF10kIUs2sIjFA6UVNIWVhf0AEXaFgoomJhoytvCKIdC_BUU3SsU_BUK-DMo0rYgIqA9Xd0iKKdK4RdQ_GdtIWPDyh_3PeK4QZ_A8Zj55CWI28NDs6X1xm5weBMaglL3bAKOHUSvu0OIvq1c85Wv96KzWdlzM0ePqi6uRo5VXVs4qsb6uRqFVcO39G1Vr8bhcWt-rwT-IeRovRlFw4TdJzvvMjYTdzTz28NTsxm_Oy8jrLY62nmOLjTqeCssmK2pwjjtEUgOi8Vmfgmai2YjemKWNI_9Os8Ee3uiuuvJBVsyOsXbo7hknQs77xz3m4lrDPZGTwkROPWmrrKhncSOlnxrOIi8TAzmXMt1146jbEyxgg19ZeETp7N2u9lg2Xrbti2mTVcCFJ13HNP-G-3jSK0',
#  'serpapi_link': 'https://serpapi.com/search.json?engine=google_ai_overview&page_token=5OWbGnicvZTbkqJIEIYv90nWG6cFbA90RxATRYE2KtLg2RsDORQIiFoo6N28y77Avs4-zRYHsbU7ZmI3NjYvioKqyvyz8iN__OG7W--v3_50omiHXykqjuMaCkPkWzUjDCgdn7cGZYc-PhjO9-PRt7i4CoGkSlDS1fn0Ynb946Cj-Va3cxl0pkd9rvlLyI_NbodezuXK-cQ9VwzM0RXL5QQwai5X7RkvDewd23gPbdurA7mSReFWax1bGyIi2WBqRZHB-_1ZIC81XLO2tefldCS_if2xBmp1mmFrCqUHZAP4NyY9ftBUAPp367ctEPDlXORVAKFDZtdvQTY6CwBU-c4lSjdBCQwE276gh3h9tZx2YjJswKkO3mER5MNYPGHur1RU2FUEguCzlQdkABF5459uK3LpJhbE-JYtVPmG8AZYyeHVyaNDUvYeEvajlQQ-XElpvCSOtWSWXgOiTERqQ1PrA3kw1AGnlYLjFzrsvribxUjpmdrw_RyojXnirGbz5C2yxuBbxoCBSwjwRwhOO4VtC4zjRJPaoMYzJQEKEQbUIiM-HaYAqJ8FFjbKcvl0T1o69UUv_-bIQJKBkif2BNReXOKh3ogQ0zcvC1kElPhiQcgcQ1KZdAEJICYxu_mxDoCSlB3hyR6ezjWRqZL5hoXAnIBeLMqxIJESYsIJyqsmFulJeb6pn36Wk8oDgUSKgQ32qucSH2G2DaJMa-kW5koRv3gk4KvSPhh8xPlm6hclF0-n_XC4Yd6idQKXtNeaajiyJdluaWpR8jBY_4Mf3_i_oNAIFP0bFLt7KLQSiru2kF10kIUs2sIjFA6UVNIWVhf0AEXaFgoomJhoytvCKIdC_BUU3SsU_BUK-DMo0rYgIqA9Xd0iKKdK4RdQ_GdtIWPDyh_3PeK4QZ_A8Zj55CWI28NDs6X1xm5weBMaglL3bAKOHUSvu0OIvq1c85Wv96KzWdlzM0ePqi6uRo5VXVs4qsb6uRqFVcO39G1Vr8bhcWt-rwT-IeRovRlFw4TdJzvvMjYTdzTz28NTsxm_Oy8jrLY62nmOLjTqeCssmK2pwjjtEUgOi8Vmfgmai2YjemKWNI_9Os8Ee3uiuuvJBVsyOsXbo7hknQs77xz3m4lrDPZGTwkROPWmrrKhncSOlnxrOIi8TAzmXMt1146jbEyxgg19ZeETp7N2u9lg2Xrbti2mTVcCFJ13HNP-G-3jSK0'}
